# %%
from cogent3 import available_apps

available_apps()
# Out:
# ...
# module                   name                    composable    doc                                                                                                                                                                                                                                          input type                                       output type
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ...
