# %%
import argparse
import sys
import os

sys.path.append('../../../..')

# %%
from zeno_etl_libs.logger import get_logger
from zeno_etl_libs.db.db import DB
from zeno_etl_libs.helper.aws.s3 import S3
from zeno_etl_libs.helper import helper
from dateutil.relativedelta import relativedelta
from zeno_etl_libs.helper.google.sheet.sheet import GoogleSheet

# %%
import pandas as pd
import numpy as np
import dateutil
import datetime
from datetime import timedelta
from dateutil.tz import gettz
import gc
from zeno_etl_libs.django.api import Sql

# %%
import typing
from functools import reduce
from sklearn.preprocessing import StandardScaler

# %%
env = 'dev'
datem = ''
sqlwrite = 'yes'

# %%
os.environ['env'] = env

# %%
logger = get_logger()

rs_db = DB()
rs_db.open_connection()

s3 = S3()

schema = 'prod2-generico'
table_name = 'drug-grades'
table_info = helper.get_table_info(db=rs_db, table_name=table_name, schema=schema)

# %%
if datem=='':
    date1=date1 = datetime.date.today().strftime('%Y-%m-%d')
    # logger.info('Entry taken from params',str(date1))
else:
    date1=datem
    # logger.info('Selecting the default date as the job run date',str(date1))

q_aa = f"""
        select
            "bill-id",
            "patient-id" ,
            "store-id" ,
            "store-name" as "name",
            "drug-id" ,
            "drug-name" ,
            "type" ,
            "created-date" as "created-at" ,
            NVL(sum(case when "bill-flag" = 'gross' then quantity end),
            0) as "sold-quantity",
            NVL(sum(case when "bill-flag" = 'return' then quantity end),
            0) as "returned-quantity",
            sum("net-quantity") as "quantity",
            sum(rate) as "rate"
        from
            "prod2-generico"."sales"
        where
            datediff('day','{date1}',
            "created-date") between -180 and -1
        group by
            "bill-id",
            "patient-id" ,
            "store-id" ,
            "store-name",
            "drug-id" ,
            "drug-name" ,
            "type" ,
            "created-date"
        having
            sum("net-quantity")>0 
"""

logger.info(q_aa)

df_aa = rs_db.get_df(q_aa)
df_aa.columns = [c.replace('-', '_') for c in df_aa.columns]

# logger.info('Shape of data',str(df_aa.shape))
# Out:
# 2022-05-17 17:08:01,993 - root - INFO -
#         select
#             "bill-id",
#             "patient-id" ,
#             "store-id" ,
#             "store-name" as "name",
#             "drug-id" ,
#             "drug-name" ,
#             "type" ,
#             "created-date" as "created-at" ,
#             NVL(sum(case when "bill-flag" = 'gross' then quantity end),
#             0) as "sold-quantity",
#             NVL(sum(case when "bill-flag" = 'return' then quantity end),
#             0) as "returned-quantity",
#             sum("net-quantity") as "quantity",
#             sum(rate) as "rate"
#         from
#             "prod2-generico"."sales"
#         where
#             datediff('day','2022-05-17',
#             "created-date") between -2 and -1
#         group by
#             "bill-id",
#             "patient-id" ,
#             "store-id" ,
#             "store-name",
#             "drug-id" ,
#             "drug-name" ,
#             "type" ,
#             "created-date"
#         having
#             sum("net-quantity")>0

# %%
df_aa['quantity'].fillna(0,inplace=True)
df_aa['rate'].fillna(0,inplace=True)

df_aa['value'] = df_aa['rate'] * df_aa['quantity']

# %%
# =============================================================================
# Store opened at
# =============================================================================

q_bb = """
        SELECT
            "id",
            datediff('day' ,
            "opened-at",
            '{}') as "age"
        FROM
            "prod2-generico"."stores"
        WHERE
            datediff('day' ,
            "opened-at",
            '{}' ) < 180
""".format(date1,date1)

df_bb = rs_db.get_df(q_bb)
df_bb.columns = [c.replace('-', '_') for c in df_bb.columns]

logger.info('Shape of stores data:{}'.format(str(df_bb.shape)))

def store_age(df_bb):
    if df_bb['age'] >= 90:
        return '3-6 month'
    else:
        return '1-3 month'

df_bb['age1'] = df_bb.apply(lambda x: store_age(x), axis=1)
# Out:
# 2022-05-17 17:10:32,948 - root - INFO - Shape of stores data:(47, 2)

# %%
# =============================================================================
# quantity sold
# =============================================================================

df_qty = df_aa.groupby(['drug_id', 'store_id'])[['quantity']].sum().reset_index()
df_qty1 = df_aa.groupby(['drug_id'])[['quantity']].sum().reset_index()

# %%
# =============================================================================
# revenue
# =============================================================================

df_revenue = df_aa.groupby(['drug_id', 'store_id'])[['value']].sum().reset_index()
df_revenue1 = df_aa.groupby(['drug_id'])[['value']].sum().reset_index()
# =============================================================================
# no. of bills
# =============================================================================
df_bills = df_aa.groupby(['drug_id', 'store_id'])[['bill_id']].nunique().reset_index()
df_bills1 = df_aa.groupby(['drug_id'])[['bill_id']].nunique().reset_index()
# =============================================================================
# no. of consumers
# =============================================================================
df_consumers = df_aa.groupby(['drug_id', 'store_id'])[['patient_id']].nunique().reset_index()
df_consumers1 = df_aa.groupby(['drug_id'])[['patient_id']].nunique().reset_index()

df_aa['created_at'] = pd.to_datetime(df_aa['created_at'])

# %%
# =============================================================================
# no. of days sold
# =============================================================================

df_aa['days'] = df_aa['created_at'].dt.date
df_days = df_aa.groupby(['drug_id', 'store_id'])[['days']].nunique().reset_index()
df_days1 = df_aa.groupby(['drug_id'])[['days']].nunique().reset_index()

# =============================================================================
# recency (last sold)
# =============================================================================

days = timedelta(1)
period_end_d = pd.to_datetime(date1) - days

df_recency = df_aa.groupby(['drug_id', 'store_id'])[['created_at']].max().reset_index()
df_recency1 = df_aa.groupby(['drug_id'])[['created_at']].max().reset_index()
df_recency['recency'] = (pd.to_datetime(period_end_d) - df_recency['created_at']).dt.days

df_recency1['recency'] = (pd.to_datetime(period_end_d) - df_recency1['created_at']).dt.days

# %%
# =============================================================================
# merge all features
# =============================================================================

meg = [df_qty, df_revenue, df_bills, df_consumers, df_days, df_recency]
df_features = reduce(lambda left, right: pd.merge(left, right, on=[
    'drug_id', 'store_id'], how='outer'), meg)
del (df_features['created_at'])

meg1 = [df_qty1, df_revenue1, df_bills1, df_consumers1, df_days1, df_recency1]
df_features1 = reduce(lambda left, right: pd.merge(left, right, on=[
    'drug_id'], how='outer'), meg1)
del (df_features1['created_at'])

df_features = df_features1.append(df_features)

df_features['store_id'] = df_features['store_id'].fillna(999)

df_features = df_features.reset_index().drop('index', axis=1)

# %%
# =============================================================================
# creating standard scaler store wise
# =============================================================================

temp_normalise = df_features[['store_id', 'quantity', 'value', 'bill_id', 'patient_id', 'days', 'recency']]

class SklearnWrapper:
    def __init__(self, transform: typing.Callable):
        self.transform = transform

    def __call__(self, df):
        transformed = self.transform.fit_transform(df.values)
        return pd.DataFrame(transformed, columns=df.columns, index=df.index)

# This one will apply any sklearn transform you pass into it to a group.

df_rescaled = (
    temp_normalise.groupby('store_id')
        .apply(SklearnWrapper(StandardScaler()))
        .drop('store_id', axis=1)
)

temp2_normalise = df_rescaled

# %%
# =============================================================================
# importing pca_components and appling to scaled data set.
# =============================================================================
pca_file_name= 'drug_grades/pca_components.csv'
pca_file_path= s3.download_file_from_s3(file_name=pca_file_name)

pca_components=pd.read_csv(pca_file_path,delimiter=',')


# =============================================================================
#  creating Euclidean Distance Caculator and applyin to nearest cluster
# =============================================================================
cluster_file_name= 'drug_grades/cluster_centers_1.csv'
pca_file_path= s3.download_file_from_s3(file_name=cluster_file_name)

cluster_centers_set=pd.read_csv(pca_file_path,delimiter=',')

cluster_centers_set = np.array(cluster_centers_set)

# Euclidean Distance Caculator
def dist(a, b, ax=1):
    return np.linalg.norm(a - b, axis=ax)
# Out:
# path: /Users/surbhi/PycharmProjects/etl/etl/sagemaker-jobs/src/tmp/
# path: /Users/surbhi/PycharmProjects/etl/etl/sagemaker-jobs/src/tmp/

# %%
clusters = []

test = np.dot(np.array(temp2_normalise), (np.array(pca_components).T))

for i in range(len(test)):
    distances = dist(np.array(test[i]), (cluster_centers_set))
    cluster = np.argmin(distances)
    clusters.append(cluster)

cluster_df = pd.DataFrame(clusters)
cluster_df.columns = ['final_cluster']

# %%
# =============================================================================
# Summary pivot 1
# =============================================================================

test_df = pd.DataFrame(test)
cluster_lvl_1 = pd.merge(test_df, cluster_df,
                         right_index=True, left_index=True)

cluster_lvl1_output = pd.merge(cluster_lvl_1, df_features, how='inner',
                               left_index=True, right_index=True)

cluster_lvl1_output_pivot = cluster_lvl1_output.groupby(['final_cluster', 'store_id'],
                                                        as_index=False).agg({'drug_id': ['count'],
                                                                             'value': ['sum'],
                                                                             'bill_id': ['mean'],
                                                                             'patient_id': ['mean'],
                                                                             'days': ['mean'],
                                                                             'recency': ['mean']}).reset_index(
    drop=True)
cluster_lvl1_output_pivot.columns = ['_'.join(x) for x in
                                     cluster_lvl1_output_pivot.columns.ravel()]


cluster_lvl1_output_pivot_name = 'drug_grades/{}.csv'.format(datetime.datetime.now().strftime('%Y-%m-%d-%H-%M-%S'))

# Uploading File to S3
s3.save_df_to_s3(df=cluster_lvl1_output_pivot, file_name=cluster_lvl1_output_pivot_name)
# Out:
# 's3://aws-glue-temporary-921939243643-ap-south-1/drug_grades/2022-05-17-17-16-15.csv'

# %%
# =============================================================================
# # 2nd level
# =============================================================================

# =============================================================================
# Further split of large cluster
# =============================================================================

further_split_lvl2 = cluster_lvl1_output[cluster_lvl1_output['final_cluster'] == 0]
# change features here if needed
further_split_lvl2 = pd.DataFrame(further_split_lvl2[[0, 1, 2, 3]])

further_split_lvl2_mat = np.array(further_split_lvl2)

cluster2_file_name= 'drug_grades/cluster_centers_2.csv'
pca_file_path= s3.download_file_from_s3(file_name=cluster2_file_name)

cluster_centers_set2=pd.read_csv(pca_file_path,delimiter=',')

cluster_centers_set2 = np.array(cluster_centers_set2)

clusters_lvl2 = []

for i in range(len(further_split_lvl2)):
    distances = dist((further_split_lvl2_mat[i]), (cluster_centers_set2))
    clusterlvl2 = np.argmin(distances)
    clusters_lvl2.append(clusterlvl2)

further_split_lvl2_df = pd.DataFrame(further_split_lvl2)

further_split_lvl2_df['final_cluster_lvl2'] = clusters_lvl2
# Out:
# path: /Users/surbhi/PycharmProjects/etl/etl/sagemaker-jobs/src/tmp/

# %%
# =============================================================================
# Summary pivot 2
# =============================================================================

cluster_lvl2_output = pd.merge(cluster_lvl1_output, further_split_lvl2_df[['final_cluster_lvl2']],
                               how='inner',
                               left_index=True, right_index=True)

cluster_lvl2_output_pivot = cluster_lvl2_output.groupby(['final_cluster_lvl2', 'store_id'],
                                                        as_index=False).agg({'drug_id': ['count'],
                                                                             'value': ['sum'],
                                                                             'bill_id': ['mean'],
                                                                             'patient_id': ['mean'],
                                                                             'days': ['mean'],
                                                                             'recency': ['mean']}).reset_index(
    drop=True)

cluster_lvl2_output_pivot.columns = ['_'.join(x) for x in
                                     cluster_lvl2_output_pivot.columns.ravel()]


cluster_lvl2_output_pivot_name = 'drug_grades/{}.csv'.format(datetime.datetime.now().strftime('%Y-%m-%d-%H-%M-%S'))

# Uploading File to S3
s3.save_df_to_s3(df=cluster_lvl2_output_pivot, file_name=cluster_lvl2_output_pivot_name)
# Out:
# 's3://aws-glue-temporary-921939243643-ap-south-1/drug_grades/2022-05-17-17-17-01.csv'

# %%
# =============================================================================
# Final cluster
# =============================================================================

cluster_file = cluster_lvl1_output[cluster_lvl1_output['final_cluster'] != 0]

final_cluster_file = cluster_file.append(cluster_lvl2_output)

final_cluster_file['cluster'] = final_cluster_file['final_cluster'
                                ].astype(str) + '_' + final_cluster_file['final_cluster_lvl2'].astype(str)

final_output_pivot = final_cluster_file.groupby(['cluster', 'store_id'],
                                                as_index=False).agg({'drug_id': ['count'],
                                                                     'value': ['sum'],
                                                                     'bill_id': ['mean'],
                                                                     'patient_id': ['mean'],
                                                                     'days': ['mean'],
                                                                     'recency': ['mean']}).reset_index(drop=True)

final_output_pivot.columns = ['_'.join(x) for x in
                              final_output_pivot.columns.ravel()]

final_output_pivot['drug%'] = final_output_pivot['drug_id_count'
                              ] / final_output_pivot['drug_id_count'].sum()

final_output_pivot['spend%'] = final_output_pivot['value_sum'
                               ] / final_output_pivot['value_sum'].sum()

final_output_pivot['drug%']=final_output_pivot['drug%'].astype('float64')
final_output_pivot['spend%']=final_output_pivot['spend%'].astype('float64')

final_output_pivot['factor'] = final_output_pivot['spend%'] / final_output_pivot['drug%']

# %%
# =============================================================================
# cluster allocation
# =============================================================================

new_store = df_bb['id'].values

new_store1 = df_bb['id'][df_bb['age1'] == '3-6 month'].values

new_store2 = df_bb['id'][df_bb['age1'] == '1-3 month'].values

new_store1_cluster = final_cluster_file[final_cluster_file.store_id.isin(new_store1)]

new_store2_cluster = final_cluster_file[final_cluster_file.store_id.isin(new_store2)]

Enterprise_cluster = final_cluster_file[final_cluster_file.store_id == 999]

old_stores_cluster = final_cluster_file[(~final_cluster_file.store_id.isin(new_store)) &
                                        (final_cluster_file.store_id != 999)]

new_store1_cluster.drop(['cluster'], axis=1, inplace=True)

new_store2_cluster.drop(['cluster'], axis=1, inplace=True)

new_store1_predict = pd.merge(new_store1_cluster, Enterprise_cluster[['drug_id', 'cluster']], how='left',
                              left_on='drug_id', right_on='drug_id')
# Out:
# /Users/surbhi/.conda/envs/etl/lib/python3.6/site-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
for i in range(len(new_store2)):
    Enterprise_temp = Enterprise_cluster.copy()
    Enterprise_temp['new_store_id'] = new_store2[i]
    if i == 0:
        new_store2_predict_data = Enterprise_temp
    else:
        new_store2_predict_data = new_store2_predict_data.append(Enterprise_temp)

new_store2_predict = new_store2_predict_data

del new_store2_predict['store_id']

new_store2_predict = new_store2_predict.rename({'new_store_id': 'store_id'}, axis=1)

# %%
cluster_all = new_store1_predict.append(new_store2_predict)

cluster_all = cluster_all.append(Enterprise_cluster)

cluster_all = cluster_all.append(old_stores_cluster)

# =============================================================================
# Summary report
# =============================================================================

cluster_all_pivote = cluster_all.groupby(['cluster', 'store_id'],
                                         as_index=False).agg({'drug_id': ['count'],
                                                              'value': ['sum'],
                                                              'bill_id': ['mean'],
                                                              'patient_id': ['mean'],
                                                              'days': ['mean'],
                                                              'recency': ['mean']}).reset_index(drop=True)

cluster_all_pivote.columns = ['_'.join(x) for x in
                              cluster_all_pivote.columns.ravel()]

cluster_all_pivote['drug%'] = cluster_all_pivote['drug_id_count'
                              ] / cluster_all_pivote['drug_id_count'].sum()

cluster_all_pivote['spend%'] = cluster_all_pivote['value_sum'
                               ] / cluster_all_pivote['value_sum'].sum()

cluster_all_pivote['drug%'] = cluster_all_pivote['drug%'].astype('float64')
cluster_all_pivote['spend%'] = cluster_all_pivote['spend%'].astype('float64')

cluster_all_pivote['factor'] = cluster_all_pivote['spend%'
                               ] / cluster_all_pivote['drug%']


cluster_all_pivote_name = 'drug_grades/{}.csv'.format(datetime.datetime.now().strftime('%Y-%m-%d-%H-%M-%S'))

# Uploading File to S3
s3.save_df_to_s3(df=cluster_all_pivote, file_name=cluster_all_pivote_name)
# Out:
# 's3://aws-glue-temporary-921939243643-ap-south-1/drug_grades/2022-05-17-17-17-45.csv'

# %%
# =============================================================================
# Assigning Cluster
# =============================================================================

def assign_cluster(cluster_all):
    if cluster_all['cluster'] == '1_nan':
        return 'A1'
    elif cluster_all['cluster'] == '2_nan':
        return 'A1'
    elif cluster_all['cluster'] == '4_nan':
        return 'A2'
    elif cluster_all['cluster'] == '0_2.0':
        return 'B'
    elif cluster_all['cluster'] == '3_nan':
        return 'D'
    elif cluster_all['cluster'] == '0_0.0':
        return 'C'
    elif cluster_all['cluster'] == '0_1.0':
        return 'C'
    else:
        return cluster_all['cluster']

cluster_all['grade'] = cluster_all.apply(lambda row: assign_cluster(row), axis=1)


cluster_all_name = 'drug_grades/{}.csv'.format(datetime.datetime.now().strftime('%Y-%m-%d-%H-%M-%S'))

# Uploading File to S3
s3.save_df_to_s3(df=cluster_all, file_name=cluster_all_name)
# Out:
# 's3://aws-glue-temporary-921939243643-ap-south-1/drug_grades/2022-05-17-17-18-07.csv'

# %%
cluster_all_pivote1 = cluster_all.groupby(['grade', 'store_id'],
                                          as_index=False).agg({'drug_id': ['count'],
                                                               'value': ['sum'],
                                                               'bill_id': ['mean'],
                                                               'patient_id': ['mean'],
                                                               'days': ['mean'],
                                                               'recency': ['mean']}).reset_index(drop=True)

cluster_all_pivote1.columns = ['_'.join(x) for x in
                               cluster_all_pivote1.columns.ravel()]

# %%
cluster_all_pivote1['drug%'] = cluster_all_pivote1['drug_id_count'
                               ] / cluster_all_pivote1['drug_id_count'].sum()

cluster_all_pivote1['spend%'] = cluster_all_pivote1['value_sum'
                                ] / cluster_all_pivote1['value_sum'].sum()

cluster_all_pivote1['drug%'] = cluster_all_pivote1['drug%'].astype('float64')

cluster_all_pivote1['spend%'] = cluster_all_pivote1['spend%'].astype('float64')

cluster_all_pivote1['factor'] = cluster_all_pivote1['spend%'
                                ] / cluster_all_pivote1['drug%']



cluster_all_pivote1_name = 'drug_grades/{}.csv'.format(datetime.datetime.now().strftime('%Y-%m-%d-%H-%M-%S'))

# Uploading File to S3
s3.save_df_to_s3(df=cluster_all_pivote1, file_name=cluster_all_pivote1_name)
# Out:
# 's3://aws-glue-temporary-921939243643-ap-south-1/drug_grades/2022-05-17-17-18-34.csv'

# %%
final_data = cluster_all[['store_id', 'drug_id', 'grade']]
final_data['calculation_date'] = date1

rs_db_write = DB(read_only=False)
rs_db_write.open_connection()


final_data.columns = [c.replace('_', '-') for c in final_data.columns]
final_data['created-at'] = datetime.datetime.now()
# Out:
# /Users/surbhi/.conda/envs/etl/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/surbhi/.conda/envs/etl/lib/python3.6/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
final_data['store-id'] = final_data['store-id'].astype(int)
final_data['drug-id'] = final_data['drug-id'].astype(int)
s3.write_df_to_db(df=final_data[table_info['column_name']], table_name=table_name, db=rs_db_write,
                  schema=schema)

'''getting current grades and replacing them with new if changed'''
new_drug_entries = pd.DataFrame()
missed_entries = pd.DataFrame()
# Out:
# /Users/surbhi/.conda/envs/etl/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/surbhi/.conda/envs/etl/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# S3 object(uri: s3://aws-glue-temporary-921939243643-ap-south-1/temp_1652790173458.csv) delete response: {'ResponseMetadata': {'RequestId': '2R6YKTRKKAMMNVYE', 'HostId': 'jz0VGddCZ3eeOdk37iUkDHDccnhzjL8QJLaJXQ/NJl1L6Bq/RESyVHuRCCq3d+9/hiPOPb7zkAs=', 'HTTPStatusCode': 204, 'HTTPHeaders': {'x-amz-id-2': 'jz0VGddCZ3eeOdk37iUkDHDccnhzjL8QJLaJXQ/NJl1L6Bq/RESyVHuRCCq3d+9/hiPOPb7zkAs=', 'x-amz-request-id': '2R6YKTRKKAMMNVYE', 'date': 'Tue, 17 May 2022 12:23:08 GMT', 'server': 'AmazonS3'}, 'RetryAttempts': 0}}

# %%
for store_id in final_data['store-id'].unique():
    if sqlwrite == 'yes':
        if store_id != 999:

            current_grade_query = f'''
                SELECT
                    id,
                    "store-id",
                    "drug-id",
                    "drug-grade"
                FROM "prod2-generico"."drug-order-info-data"
                WHERE "store-id" = {store_id}
            '''

            current_grade = rs_db.get_df(current_grade_query)
            current_grade.columns = [c.replace('-', '_') for c in current_grade.columns]

            current_grade.columns = list(map(
                lambda s: str.replace(s, '-', '_'),
                list(current_grade.columns.values)
            ))

            final_data_store = final_data.loc[
                final_data['store-id'] == store_id,
                ['store-id', 'drug-id', 'grade']]
            final_data_store.columns = [c.replace('-', '_') for c in final_data_store.columns]
            grade_joined = current_grade.merge(
                final_data_store, on=['store_id', 'drug_id'], how='outer')
            grade_joined.loc[grade_joined['grade'].isna(), 'grade'] = 'NA'
            new_drug_entries = new_drug_entries.append(
                grade_joined[grade_joined['id'].isna()])
            grade_joined = grade_joined[~grade_joined['id'].isna()]

            grade_joined['change_flag'] = np.where(
                grade_joined['drug_grade'] == grade_joined['grade'],
                'same', 'changed')

            logger.info('Store ' + str(store_id))
            logger.info('Total grades calculated' + str(final_data_store.shape[0]))
            logger.info('Grades changed' + str(grade_joined[
                                                   grade_joined['change_flag'] == 'changed'].shape[0]))

            grades_to_change = grade_joined.loc[
                grade_joined['change_flag'] == 'changed',
                ['id', 'store_id', 'drug_id', 'grade']]
            grades_to_change.columns = ['id', 'store_id', 'drug_id', 'drug_grade']
            data_to_be_updated_list = list(
                grades_to_change[['id', 'drug_grade']].apply(dict, axis=1))

            sql = Sql()

            sql.update(
                {'table': 'DrugOrderInfoData',
                 'data_to_be_updated': data_to_be_updated_list}, logger
            )

            update_test_query = f'''
                SELECT
                    "store-id",
                    "drug-id",
                    "drug-grade"
                FROM "prod2-generico"."drug-order-info-data"
                WHERE "store-id" = {store_id}
                    and "grade-updated-at" >= CURRENT_TIMESTAMP - INTERVAL '10 MINUTE'
                    and "grade-updated-at" < CURRENT_TIMESTAMP
            '''

            update_test = rs_db.get_df(update_test_query)
            update_test.columns = [c.replace('-', '_') for c in update_test.columns]

            update_test.columns = list(map(
                lambda s: str.replace(s, '-', '_'),
                list(update_test.columns.values)
            ))
            update_test = grades_to_change.merge(
                update_test, how='left', on=['store_id', 'drug_id'],
                suffixes=('', '_updated'))
            mismatch = update_test[
                update_test['drug_grade'] != update_test['drug_grade_updated']]
            missed_entries = missed_entries.append(mismatch)
            logger.info('For store ' + str(store_id) + 'update mismatch count'
                        + str(mismatch.shape[0]))


new_drug_entries_name = 'drug_grades/{}.csv'.format(new_drug_entries)

# Uploading File to S3
s3.save_df_to_s3(df=new_drug_entries[
    ['store_id', 'drug_id', 'drug_grade']], file_name=new_drug_entries_name)


missed_entries_name = 'drug_grades/{}.csv'.format(missed_entries)

# Uploading File to S3
s3.save_df_to_s3(df=missed_entries, file_name=missed_entries_name)
# Out:
# 2022-05-17 18:07:03,942 - root - INFO - Store 285
# 2022-05-17 18:07:03,943 - root - INFO - Total grades calculated185
# 2022-05-17 18:07:03,955 - root - INFO - Grades changed185
# 2022-05-17 18:07:04,485 - root - INFO - For store 285update mismatch count185
# 2022-05-17 18:07:05,743 - root - INFO - Store 296
# 2022-05-17 18:07:05,744 - root - INFO - Total grades calculated169
# 2022-05-17 18:07:05,755 - root - INFO - Grades changed169
# 2022-05-17 18:07:05,932 - root - INFO - For store 296update mismatch count169
# 2022-05-17 18:07:07,057 - root - INFO - Store 270
# 2022-05-17 18:07:07,058 - root - INFO - Total grades calculated141
# 2022-05-17 18:07:07,069 - root - INFO - Grades changed141
# 2022-05-17 18:07:07,229 - root - INFO - For store 270update mismatch count141
# 2022-05-17 18:07:08,354 - root - INFO - Store 278
# 2022-05-17 18:07:08,354 - root - INFO - Total grades calculated285
# 2022-05-17 18:07:08,365 - root - INFO - Grades changed285
# 2022-05-17 18:07:08,533 - root - INFO - For store 278update mismatch count285
# 2022-05-17 18:07:09,557 - root - INFO - Store 284
# 2022-05-17 18:07:09,557 - root - INFO - Total grades calculated106
# 2022-05-17 18:07:09,569 - root - INFO - Grades changed106
# 2022-05-17 18:07:09,954 - root - INFO - For store 284update mismatch count106
# 2022-05-17 18:07:11,228 - root - INFO - Store 288
# 2022-05-17 18:07:11,228 - root - INFO - Total grades calculated274
# 2022-05-17 18:07:11,240 - root - INFO - Grades changed274
# 2022-05-17 18:07:11,450 - root - INFO - For store 288update mismatch count274
# 2022-05-17 18:07:12,650 - root - INFO - Store 286
# 2022-05-17 18:07:12,650 - root - INFO - Total grades calculated131
# 2022-05-17 18:07:12,661 - root - INFO - Grades changed131
# 2022-05-17 18:07:12,821 - root - INFO - For store 286update mismatch count131
# 2022-05-17 18:07:14,188 - root - INFO - Store 276
# 2022-05-17 18:07:14,188 - root - INFO - Total grades calculated285
# 2022-05-17 18:07:14,200 - root - INFO - Grades changed285
# 2022-05-17 18:07:14,502 - root - INFO - For store 276update mismatch count285
# 2022-05-17 18:07:15,685 - root - INFO - Store 280
# 2022-05-17 18:07:15,685 - root - INFO - Total grades calculated176
# 2022-05-17 18:07:15,699 - root - INFO - Grades changed176
# 2022-05-17 18:07:15,855 - root - INFO - For store 280update mismatch count176
# 2022-05-17 18:07:16,976 - root - INFO - Store 282
# 2022-05-17 18:07:16,977 - root - INFO - Total grades calculated161
# 2022-05-17 18:07:16,988 - root - INFO - Grades changed161
# 2022-05-17 18:07:17,254 - root - INFO - For store 282update mismatch count161
# 2022-05-17 18:07:18,274 - root - INFO - Store 290
# 2022-05-17 18:07:18,275 - root - INFO - Total grades calculated187
# 2022-05-17 18:07:18,286 - root - INFO - Grades changed187
# 2022-05-17 18:07:18,530 - root - INFO - For store 290update mismatch count187
# 2022-05-17 18:07:19,743 - root - INFO - Store 291
# 2022-05-17 18:07:19,744 - root - INFO - Total grades calculated65
# 2022-05-17 18:07:19,756 - root - INFO - Grades changed65
# 2022-05-17 18:07:19,920 - root - INFO - For store 291update mismatch count65
# 2022-05-17 18:07:20,956 - root - INFO - Store 293
# 2022-05-17 18:07:20,957 - root - INFO - Total grades calculated96
# 2022-05-17 18:07:20,968 - root - INFO - Grades changed96
# 2022-05-17 18:07:21,369 - root - INFO - For store 293update mismatch count96
# 2022-05-17 18:07:22,483 - root - INFO - Store 295
# 2022-05-17 18:07:22,484 - root - INFO - Total grades calculated113
# 2022-05-17 18:07:22,496 - root - INFO - Grades changed113
# 2022-05-17 18:07:22,685 - root - INFO - For store 295update mismatch count113
# 2022-05-17 18:07:23,887 - root - INFO - Store 302
# 2022-05-17 18:07:23,887 - root - INFO - Total grades calculated142
# 2022-05-17 18:07:23,898 - root - INFO - Grades changed142
# 2022-05-17 18:07:24,072 - root - INFO - For store 302update mismatch count142
# 2022-05-17 18:07:25,149 - root - INFO - Store 292
# 2022-05-17 18:07:25,150 - root - INFO - Total grades calculated123
# 2022-05-17 18:07:25,161 - root - INFO - Grades changed123
# 2022-05-17 18:07:25,322 - root - INFO - For store 292update mismatch count123
# 2022-05-17 18:07:26,501 - root - INFO - Store 283
# 2022-05-17 18:07:26,502 - root - INFO - Total grades calculated104
# 2022-05-17 18:07:26,515 - root - INFO - Grades changed104
# 2022-05-17 18:07:26,670 - root - INFO - For store 283update mismatch count104
# 2022-05-17 18:07:27,928 - root - INFO - Store 299
# 2022-05-17 18:07:27,928 - root - INFO - Total grades calculated171
# 2022-05-17 18:07:27,939 - root - INFO - Grades changed171
# 2022-05-17 18:07:28,106 - root - INFO - For store 299update mismatch count171
# 2022-05-17 18:07:29,263 - root - INFO - Store 306
# 2022-05-17 18:07:29,263 - root - INFO - Total grades calculated136
# 2022-05-17 18:07:29,274 - root - INFO - Grades changed136
# 2022-05-17 18:07:29,427 - root - INFO - For store 306update mismatch count136
# 2022-05-17 18:07:30,603 - root - INFO - Store 301
# 2022-05-17 18:07:30,604 - root - INFO - Total grades calculated185
# 2022-05-17 18:07:30,616 - root - INFO - Grades changed185
# 2022-05-17 18:07:30,776 - root - INFO - For store 301update mismatch count185
# 2022-05-17 18:07:31,858 - root - INFO - Store 297
# 2022-05-17 18:07:31,858 - root - INFO - Total grades calculated115
# 2022-05-17 18:07:31,871 - root - INFO - Grades changed115
# 2022-05-17 18:07:32,018 - root - INFO - For store 297update mismatch count115
# 2022-05-17 18:07:33,155 - root - INFO - Store 308
# 2022-05-17 18:07:33,156 - root - INFO - Total grades calculated91
# 2022-05-17 18:07:33,167 - root - INFO - Grades changed91
# 2022-05-17 18:07:33,399 - root - INFO - For store 308update mismatch count91
# 2022-05-17 18:07:34,664 - root - INFO - Store 289
# 2022-05-17 18:07:34,664 - root - INFO - Total grades calculated124
# 2022-05-17 18:07:34,675 - root - INFO - Grades changed124
# 2022-05-17 18:07:34,889 - root - INFO - For store 289update mismatch count124
# 2022-05-17 18:07:36,006 - root - INFO - Store 303
# 2022-05-17 18:07:36,007 - root - INFO - Total grades calculated90
# 2022-05-17 18:07:36,017 - root - INFO - Grades changed90
# 2022-05-17 18:07:36,245 - root - INFO - For store 303update mismatch count90
# 2022-05-17 18:07:37,310 - root - INFO - Store 287
# 2022-05-17 18:07:37,311 - root - INFO - Total grades calculated194
# 2022-05-17 18:07:37,322 - root - INFO - Grades changed194
# 2022-05-17 18:07:37,507 - root - INFO - For store 287update mismatch count194
# 2022-05-17 18:07:38,637 - root - INFO - Store 298
# 2022-05-17 18:07:38,637 - root - INFO - Total grades calculated8710
# 2022-05-17 18:07:38,649 - root - INFO - Grades changed8710
# 2022-05-17 18:07:39,060 - root - INFO - For store 298update mismatch count8710
# 2022-05-17 18:07:40,160 - root - INFO - Store 313
# 2022-05-17 18:07:40,160 - root - INFO - Total grades calculated8710
# 2022-05-17 18:07:40,172 - root - INFO - Grades changed8710
# 2022-05-17 18:07:40,667 - root - INFO - For store 313update mismatch count8710
# 2022-05-17 18:07:42,269 - root - INFO - Store 318
# 2022-05-17 18:07:42,269 - root - INFO - Total grades calculated8710
# 2022-05-17 18:07:42,281 - root - INFO - Grades changed8710
# 2022-05-17 18:07:42,839 - root - INFO - For store 318update mismatch count8710
# 2022-05-17 18:07:44,384 - root - INFO - Store 315
# 2022-05-17 18:07:44,384 - root - INFO - Total grades calculated8710
# 2022-05-17 18:07:44,396 - root - INFO - Grades changed8710
# 2022-05-17 18:07:44,930 - root - INFO - For store 315update mismatch count8710
# 2022-05-17 18:07:46,530 - root - INFO - Store 311
# 2022-05-17 18:07:46,530 - root - INFO - Total grades calculated8710
# 2022-05-17 18:07:46,542 - root - INFO - Grades changed8710
# 2022-05-17 18:07:47,427 - root - INFO - For store 311update mismatch count8710
# 2022-05-17 18:07:49,345 - root - INFO - Store 317
# 2022-05-17 18:07:49,346 - root - INFO - Total grades calculated8710
# 2022-05-17 18:07:49,357 - root - INFO - Grades changed8710
# 2022-05-17 18:07:49,910 - root - INFO - For store 317update mismatch count8710
# 2022-05-17 18:07:51,603 - root - INFO - Store 322
# 2022-05-17 18:07:51,603 - root - INFO - Total grades calculated8710
# 2022-05-17 18:07:51,615 - root - INFO - Grades changed8710
# 2022-05-17 18:07:52,123 - root - INFO - For store 322update mismatch count8710
# 2022-05-17 18:07:53,814 - root - INFO - Store 328
# 2022-05-17 18:07:53,814 - root - INFO - Total grades calculated8710
# 2022-05-17 18:07:53,826 - root - INFO - Grades changed8710
# 2022-05-17 18:07:54,612 - root - INFO - For store 328update mismatch count8710
# 2022-05-17 18:07:56,093 - root - INFO - Store 325
# 2022-05-17 18:07:56,093 - root - INFO - Total grades calculated8710
# 2022-05-17 18:07:56,105 - root - INFO - Grades changed8710
# 2022-05-17 18:07:56,758 - root - INFO - For store 325update mismatch count8710
# 2022-05-17 18:07:58,367 - root - INFO - Store 329
# 2022-05-17 18:07:58,367 - root - INFO - Total grades calculated8710
# 2022-05-17 18:07:58,379 - root - INFO - Grades changed8710
# 2022-05-17 18:07:58,830 - root - INFO - For store 329update mismatch count8710
# 2022-05-17 18:08:00,334 - root - INFO - Store 332
# 2022-05-17 18:08:00,334 - root - INFO - Total grades calculated8710
# 2022-05-17 18:08:00,347 - root - INFO - Grades changed8710
# 2022-05-17 18:08:00,936 - root - INFO - For store 332update mismatch count8710
# 2022-05-17 18:08:02,575 - root - INFO - Store 294
# 2022-05-17 18:08:02,575 - root - INFO - Total grades calculated8710
# 2022-05-17 18:08:02,587 - root - INFO - Grades changed8710
# 2022-05-17 18:08:03,103 - root - INFO - For store 294update mismatch count8710
# 2022-05-17 18:08:04,541 - root - INFO - Store 320
# 2022-05-17 18:08:04,542 - root - INFO - Total grades calculated8710
# 2022-05-17 18:08:04,553 - root - INFO - Grades changed8710
# 2022-05-17 18:08:05,792 - root - INFO - For store 320update mismatch count8710
# 2022-05-17 18:08:07,863 - root - INFO - Store 324
# 2022-05-17 18:08:07,864 - root - INFO - Total grades calculated8710
# 2022-05-17 18:08:07,876 - root - INFO - Grades changed8710
# 2022-05-17 18:08:08,305 - root - INFO - For store 324update mismatch count8710
# 2022-05-17 18:08:09,758 - root - INFO - Store 309
# 2022-05-17 18:08:09,759 - root - INFO - Total grades calculated8710
# 2022-05-17 18:08:09,772 - root - INFO - Grades changed8710
# 2022-05-17 18:08:10,251 - root - INFO - For store 309update mismatch count8710
# 2022-05-17 18:08:11,596 - root - INFO - Store 312
# 2022-05-17 18:08:11,597 - root - INFO - Total grades calculated8710
# 2022-05-17 18:08:11,610 - root - INFO - Grades changed8710
# 2022-05-17 18:08:12,036 - root - INFO - For store 312update mismatch count8710
# 2022-05-17 18:08:13,244 - root - INFO - Store 316
# 2022-05-17 18:08:13,245 - root - INFO - Total grades calculated8710
# 2022-05-17 18:08:13,256 - root - INFO - Grades changed8710
# 2022-05-17 18:08:13,829 - root - INFO - For store 316update mismatch count8710
# 2022-05-17 18:08:15,535 - root - INFO - Store 319
# 2022-05-17 18:08:15,536 - root - INFO - Total grades calculated8710
# 2022-05-17 18:08:15,548 - root - INFO - Grades changed8710
# 2022-05-17 18:08:16,120 - root - INFO - For store 319update mismatch count8710
# 2022-05-17 18:08:17,398 - root - INFO - Store 304
# 2022-05-17 18:08:17,398 - root - INFO - Total grades calculated8710
# 2022-05-17 18:08:17,410 - root - INFO - Grades changed8710
# 2022-05-17 18:08:17,815 - root - INFO - For store 304update mismatch count8710
# 2022-05-17 18:08:19,110 - root - INFO - Store 300
# 2022-05-17 18:08:19,111 - root - INFO - Total grades calculated8710
# 2022-05-17 18:08:19,123 - root - INFO - Grades changed8710
# 2022-05-17 18:08:19,550 - root - INFO - For store 300update mismatch count8710
# 2022-05-17 18:08:20,752 - root - INFO - Store 310
# 2022-05-17 18:08:20,752 - root - INFO - Total grades calculated8710
# 2022-05-17 18:08:20,764 - root - INFO - Grades changed8710
# 2022-05-17 18:08:21,243 - root - INFO - For store 310update mismatch count8710
# 2022-05-17 18:08:22,469 - root - INFO - Store 321
# 2022-05-17 18:08:22,470 - root - INFO - Total grades calculated8710
# 2022-05-17 18:08:22,481 - root - INFO - Grades changed8710
# 2022-05-17 18:08:22,954 - root - INFO - For store 321update mismatch count8710
# 2022-05-17 18:08:23,979 - root - INFO - Store 45
# 2022-05-17 18:08:23,979 - root - INFO - Total grades calculated534
# 2022-05-17 18:08:23,991 - root - INFO - Grades changed5883
# 2022-05-17 18:08:24,753 - root - INFO - For store 45update mismatch count5883
# 2022-05-17 18:08:25,901 - root - INFO - Store 215
# 2022-05-17 18:08:25,901 - root - INFO - Total grades calculated348
# 2022-05-17 18:08:25,912 - root - INFO - Grades changed4817
# 2022-05-17 18:08:26,421 - root - INFO - For store 215update mismatch count4817
# 2022-05-17 18:08:27,532 - root - INFO - Store 130
# 2022-05-17 18:08:27,532 - root - INFO - Total grades calculated636
# 2022-05-17 18:08:27,543 - root - INFO - Grades changed6255
# 2022-05-17 18:08:27,919 - root - INFO - For store 130update mismatch count6255
# 2022-05-17 18:08:29,058 - root - INFO - Store 7
# 2022-05-17 18:08:29,058 - root - INFO - Total grades calculated427
# 2022-05-17 18:08:29,069 - root - INFO - Grades changed5908
# 2022-05-17 18:08:29,472 - root - INFO - For store 7update mismatch count5908
# 2022-05-17 18:08:30,749 - root - INFO - Store 195
# 2022-05-17 18:08:30,749 - root - INFO - Total grades calculated352
# 2022-05-17 18:08:30,761 - root - INFO - Grades changed4870
# 2022-05-17 18:08:31,173 - root - INFO - For store 195update mismatch count4870
# 2022-05-17 18:08:32,763 - root - INFO - Store 20
# 2022-05-17 18:08:32,764 - root - INFO - Total grades calculated552
# 2022-05-17 18:08:32,775 - root - INFO - Grades changed5440
# 2022-05-17 18:08:33,262 - root - INFO - For store 20update mismatch count5440
# 2022-05-17 18:08:34,432 - root - INFO - Store 63
# 2022-05-17 18:08:34,432 - root - INFO - Total grades calculated741
# 2022-05-17 18:08:34,444 - root - INFO - Grades changed6699
# 2022-05-17 18:08:34,843 - root - INFO - For store 63update mismatch count6699
# 2022-05-17 18:08:35,897 - root - INFO - Store 264
# 2022-05-17 18:08:35,898 - root - INFO - Total grades calculated399
# 2022-05-17 18:08:35,909 - root - INFO - Grades changed399
# 2022-05-17 18:08:36,216 - root - INFO - For store 264update mismatch count399
# 2022-05-17 18:08:37,454 - root - INFO - Store 152
# 2022-05-17 18:08:37,455 - root - INFO - Total grades calculated402
# 2022-05-17 18:08:37,466 - root - INFO - Grades changed4623
# 2022-05-17 18:08:38,091 - root - INFO - For store 152update mismatch count4623
# 2022-05-17 18:08:39,202 - root - INFO - Store 16
# 2022-05-17 18:08:39,202 - root - INFO - Total grades calculated589
# 2022-05-17 18:08:39,214 - root - INFO - Grades changed6050
# 2022-05-17 18:08:39,687 - root - INFO - For store 16update mismatch count6050
# 2022-05-17 18:08:40,760 - root - INFO - Store 134
# 2022-05-17 18:08:40,760 - root - INFO - Total grades calculated510
# 2022-05-17 18:08:40,773 - root - INFO - Grades changed5948
# 2022-05-17 18:08:41,268 - root - INFO - For store 134update mismatch count5948
# 2022-05-17 18:08:42,444 - root - INFO - Store 184
# 2022-05-17 18:08:42,445 - root - INFO - Total grades calculated365
# 2022-05-17 18:08:42,456 - root - INFO - Grades changed4695
# 2022-05-17 18:08:42,827 - root - INFO - For store 184update mismatch count4695
# 2022-05-17 18:08:43,990 - root - INFO - Store 4
# 2022-05-17 18:08:43,990 - root - INFO - Total grades calculated565
# 2022-05-17 18:08:44,002 - root - INFO - Grades changed6885
# 2022-05-17 18:08:44,423 - root - INFO - For store 4update mismatch count6885
# 2022-05-17 18:08:45,574 - root - INFO - Store 57
# 2022-05-17 18:08:45,574 - root - INFO - Total grades calculated520
# 2022-05-17 18:08:45,586 - root - INFO - Grades changed5530
# 2022-05-17 18:08:46,083 - root - INFO - For store 57update mismatch count5530
# 2022-05-17 18:08:47,215 - root - INFO - Store 252
# 2022-05-17 18:08:47,216 - root - INFO - Total grades calculated207
# 2022-05-17 18:08:47,227 - root - INFO - Grades changed207
# 2022-05-17 18:08:47,557 - root - INFO - For store 252update mismatch count207
# 2022-05-17 18:08:49,063 - root - INFO - Store 216
# 2022-05-17 18:08:49,064 - root - INFO - Total grades calculated355
# 2022-05-17 18:08:49,075 - root - INFO - Grades changed4419
# 2022-05-17 18:08:49,432 - root - INFO - For store 216update mismatch count4419
# 2022-05-17 18:08:50,721 - root - INFO - Store 86
# 2022-05-17 18:08:50,722 - root - INFO - Total grades calculated563
# 2022-05-17 18:08:50,733 - root - INFO - Grades changed5306
# 2022-05-17 18:08:51,125 - root - INFO - For store 86update mismatch count5306
# 2022-05-17 18:08:52,493 - root - INFO - Store 28
# 2022-05-17 18:08:52,493 - root - INFO - Total grades calculated444
# 2022-05-17 18:08:52,504 - root - INFO - Grades changed5033
# 2022-05-17 18:08:52,883 - root - INFO - For store 28update mismatch count5033
# 2022-05-17 18:08:54,198 - root - INFO - Store 40
# 2022-05-17 18:08:54,198 - root - INFO - Total grades calculated600
# 2022-05-17 18:08:54,210 - root - INFO - Grades changed5791
# 2022-05-17 18:08:54,699 - root - INFO - For store 40update mismatch count5791
# 2022-05-17 18:08:56,006 - root - INFO - Store 54
# 2022-05-17 18:08:56,007 - root - INFO - Total grades calculated597
# 2022-05-17 18:08:56,018 - root - INFO - Grades changed6039
# 2022-05-17 18:08:56,445 - root - INFO - For store 54update mismatch count6039
# 2022-05-17 18:08:57,568 - root - INFO - Store 34
# 2022-05-17 18:08:57,569 - root - INFO - Total grades calculated506
# 2022-05-17 18:08:57,580 - root - INFO - Grades changed5438
# 2022-05-17 18:08:57,976 - root - INFO - For store 34update mismatch count5438
# 2022-05-17 18:08:59,164 - root - INFO - Store 43
# 2022-05-17 18:08:59,164 - root - INFO - Total grades calculated383
# 2022-05-17 18:08:59,176 - root - INFO - Grades changed4778
# 2022-05-17 18:08:59,679 - root - INFO - For store 43update mismatch count4778
# 2022-05-17 18:09:00,817 - root - INFO - Store 39
# 2022-05-17 18:09:00,817 - root - INFO - Total grades calculated482
# 2022-05-17 18:09:00,828 - root - INFO - Grades changed5357
# 2022-05-17 18:09:01,170 - root - INFO - For store 39update mismatch count5357
# 2022-05-17 18:09:02,351 - root - INFO - Store 139
# 2022-05-17 18:09:02,352 - root - INFO - Total grades calculated430
# 2022-05-17 18:09:02,363 - root - INFO - Grades changed5203
# 2022-05-17 18:09:02,948 - root - INFO - For store 139update mismatch count5203
# 2022-05-17 18:09:04,095 - root - INFO - Store 51
# 2022-05-17 18:09:04,095 - root - INFO - Total grades calculated559
# 2022-05-17 18:09:04,107 - root - INFO - Grades changed6094
# 2022-05-17 18:09:04,672 - root - INFO - For store 51update mismatch count6094
# 2022-05-17 18:09:05,852 - root - INFO - Store 193
# 2022-05-17 18:09:05,853 - root - INFO - Total grades calculated431
# 2022-05-17 18:09:05,864 - root - INFO - Grades changed4889
# 2022-05-17 18:09:06,267 - root - INFO - For store 193update mismatch count4889
# 2022-05-17 18:09:07,305 - root - INFO - Store 221
# 2022-05-17 18:09:07,305 - root - INFO - Total grades calculated561
# 2022-05-17 18:09:07,317 - root - INFO - Grades changed5503
# 2022-05-17 18:09:07,741 - root - INFO - For store 221update mismatch count5503
# 2022-05-17 18:09:08,867 - root - INFO - Store 26
# 2022-05-17 18:09:08,868 - root - INFO - Total grades calculated380
# 2022-05-17 18:09:08,879 - root - INFO - Grades changed6504
# 2022-05-17 18:09:09,783 - root - INFO - For store 26update mismatch count6504
# 2022-05-17 18:09:10,902 - root - INFO - Store 70
# 2022-05-17 18:09:10,902 - root - INFO - Total grades calculated367
# 2022-05-17 18:09:10,914 - root - INFO - Grades changed4553
# 2022-05-17 18:09:11,364 - root - INFO - For store 70update mismatch count4553
# 2022-05-17 18:09:12,516 - root - INFO - Store 17
# 2022-05-17 18:09:12,517 - root - INFO - Total grades calculated474
# 2022-05-17 18:09:12,528 - root - INFO - Grades changed4800
# 2022-05-17 18:09:12,939 - root - INFO - For store 17update mismatch count4800
# 2022-05-17 18:09:14,003 - root - INFO - Store 61
# 2022-05-17 18:09:14,003 - root - INFO - Total grades calculated359
# 2022-05-17 18:09:14,015 - root - INFO - Grades changed5184
# 2022-05-17 18:09:14,697 - root - INFO - For store 61update mismatch count5184
# 2022-05-17 18:09:15,833 - root - INFO - Store 73
# 2022-05-17 18:09:15,833 - root - INFO - Total grades calculated431
# 2022-05-17 18:09:15,845 - root - INFO - Grades changed5294
# 2022-05-17 18:09:16,303 - root - INFO - For store 73update mismatch count5294
# 2022-05-17 18:09:17,427 - root - INFO - Store 95
# 2022-05-17 18:09:17,428 - root - INFO - Total grades calculated437
# 2022-05-17 18:09:17,439 - root - INFO - Grades changed4837
# 2022-05-17 18:09:17,970 - root - INFO - For store 95update mismatch count4837
# 2022-05-17 18:09:19,121 - root - INFO - Store 97
# 2022-05-17 18:09:19,122 - root - INFO - Total grades calculated387
# 2022-05-17 18:09:19,133 - root - INFO - Grades changed4913
# 2022-05-17 18:09:19,710 - root - INFO - For store 97update mismatch count4913
# 2022-05-17 18:09:20,942 - root - INFO - Store 104
# 2022-05-17 18:09:20,942 - root - INFO - Total grades calculated522
# 2022-05-17 18:09:20,953 - root - INFO - Grades changed5643
# 2022-05-17 18:09:21,346 - root - INFO - For store 104update mismatch count5643
# 2022-05-17 18:09:22,493 - root - INFO - Store 115
# 2022-05-17 18:09:22,493 - root - INFO - Total grades calculated382
# 2022-05-17 18:09:22,505 - root - INFO - Grades changed4794
# 2022-05-17 18:09:22,904 - root - INFO - For store 115update mismatch count4794
# 2022-05-17 18:09:24,092 - root - INFO - Store 143
# 2022-05-17 18:09:24,092 - root - INFO - Total grades calculated502
# 2022-05-17 18:09:24,104 - root - INFO - Grades changed5018
# 2022-05-17 18:09:25,177 - root - INFO - For store 143update mismatch count5018
# 2022-05-17 18:09:26,257 - root - INFO - Store 154
# 2022-05-17 18:09:26,258 - root - INFO - Total grades calculated389
# 2022-05-17 18:09:26,270 - root - INFO - Grades changed4218
# 2022-05-17 18:09:26,620 - root - INFO - For store 154update mismatch count4218
# 2022-05-17 18:09:27,742 - root - INFO - Store 180
# 2022-05-17 18:09:27,743 - root - INFO - Total grades calculated249
# 2022-05-17 18:09:27,755 - root - INFO - Grades changed3647
# 2022-05-17 18:09:28,111 - root - INFO - For store 180update mismatch count3647
# 2022-05-17 18:09:29,173 - root - INFO - Store 210
# 2022-05-17 18:09:29,174 - root - INFO - Total grades calculated420
# 2022-05-17 18:09:29,187 - root - INFO - Grades changed4777
# 2022-05-17 18:09:29,561 - root - INFO - For store 210update mismatch count4777
# 2022-05-17 18:09:30,627 - root - INFO - Store 218
# 2022-05-17 18:09:30,627 - root - INFO - Total grades calculated335
# 2022-05-17 18:09:30,642 - root - INFO - Grades changed4913
# 2022-05-17 18:09:31,108 - root - INFO - For store 218update mismatch count4913
# 2022-05-17 18:09:32,154 - root - INFO - Store 225
# 2022-05-17 18:09:32,155 - root - INFO - Total grades calculated215
# 2022-05-17 18:09:32,168 - root - INFO - Grades changed3712
# 2022-05-17 18:09:32,482 - root - INFO - For store 225update mismatch count3712
# 2022-05-17 18:09:33,494 - root - INFO - Store 227
# 2022-05-17 18:09:33,495 - root - INFO - Total grades calculated326
# 2022-05-17 18:09:33,507 - root - INFO - Grades changed4447
# 2022-05-17 18:09:33,807 - root - INFO - For store 227update mismatch count4447
# 2022-05-17 18:09:34,960 - root - INFO - Store 234
# 2022-05-17 18:09:34,960 - root - INFO - Total grades calculated233
# 2022-05-17 18:09:34,974 - root - INFO - Grades changed3217
# 2022-05-17 18:09:35,538 - root - INFO - For store 234update mismatch count3217
# 2022-05-17 18:09:36,985 - root - INFO - Store 239
# 2022-05-17 18:09:36,986 - root - INFO - Total grades calculated241
# 2022-05-17 18:09:36,997 - root - INFO - Grades changed2906
# 2022-05-17 18:09:37,256 - root - INFO - For store 239update mismatch count2906
# 2022-05-17 18:09:39,121 - root - INFO - Store 253
# 2022-05-17 18:09:39,121 - root - INFO - Total grades calculated332
# 2022-05-17 18:09:39,133 - root - INFO - Grades changed332
# 2022-05-17 18:09:39,381 - root - INFO - For store 253update mismatch count332
# 2022-05-17 18:09:41,095 - root - INFO - Store 269
# 2022-05-17 18:09:41,096 - root - INFO - Total grades calculated242
# 2022-05-17 18:09:41,107 - root - INFO - Grades changed242
# 2022-05-17 18:09:41,419 - root - INFO - For store 269update mismatch count242
# 2022-05-17 18:09:42,983 - root - INFO - Store 21
# 2022-05-17 18:09:42,983 - root - INFO - Total grades calculated445
# 2022-05-17 18:09:42,995 - root - INFO - Grades changed5099
# 2022-05-17 18:09:43,424 - root - INFO - For store 21update mismatch count5099
# 2022-05-17 18:09:45,589 - root - INFO - Store 83
# 2022-05-17 18:09:45,590 - root - INFO - Total grades calculated350
# 2022-05-17 18:09:45,601 - root - INFO - Grades changed4726
# 2022-05-17 18:09:46,042 - root - INFO - For store 83update mismatch count4726
# 2022-05-17 18:09:47,971 - root - INFO - Store 2
# 2022-05-17 18:09:47,972 - root - INFO - Total grades calculated670
# 2022-05-17 18:09:47,983 - root - INFO - Grades changed7430
# 2022-05-17 18:09:48,667 - root - INFO - For store 2update mismatch count7430
# 2022-05-17 18:09:50,243 - root - INFO - Store 64
# 2022-05-17 18:09:50,243 - root - INFO - Total grades calculated529
# 2022-05-17 18:09:50,257 - root - INFO - Grades changed5605
# 2022-05-17 18:09:50,732 - root - INFO - For store 64update mismatch count5605
# 2022-05-17 18:09:52,362 - root - INFO - Store 36
# 2022-05-17 18:09:52,362 - root - INFO - Total grades calculated375
# 2022-05-17 18:09:52,375 - root - INFO - Grades changed5360
# 2022-05-17 18:09:52,788 - root - INFO - For store 36update mismatch count5360
# 2022-05-17 18:09:54,385 - root - INFO - Store 261
# 2022-05-17 18:09:54,385 - root - INFO - Total grades calculated167
# 2022-05-17 18:09:54,400 - root - INFO - Grades changed167
# 2022-05-17 18:09:54,570 - root - INFO - For store 261update mismatch count167
# 2022-05-17 18:09:55,774 - root - INFO - Store 99
# 2022-05-17 18:09:55,775 - root - INFO - Total grades calculated349
# 2022-05-17 18:09:55,788 - root - INFO - Grades changed4515
# 2022-05-17 18:09:56,282 - root - INFO - For store 99update mismatch count4515
# 2022-05-17 18:09:57,483 - root - INFO - Store 126
# 2022-05-17 18:09:57,483 - root - INFO - Total grades calculated274
# 2022-05-17 18:09:57,498 - root - INFO - Grades changed4692
# 2022-05-17 18:09:58,311 - root - INFO - For store 126update mismatch count4692
# 2022-05-17 18:09:59,733 - root - INFO - Store 13
# 2022-05-17 18:09:59,733 - root - INFO - Total grades calculated238
# 2022-05-17 18:09:59,750 - root - INFO - Grades changed4047
# 2022-05-17 18:10:00,514 - root - INFO - For store 13update mismatch count4047
# 2022-05-17 18:10:01,700 - root - INFO - Store 89
# 2022-05-17 18:10:01,701 - root - INFO - Total grades calculated379
# 2022-05-17 18:10:01,715 - root - INFO - Grades changed5005
# 2022-05-17 18:10:02,123 - root - INFO - For store 89update mismatch count5005
# 2022-05-17 18:10:03,209 - root - INFO - Store 109
# 2022-05-17 18:10:03,209 - root - INFO - Total grades calculated337
# 2022-05-17 18:10:03,223 - root - INFO - Grades changed5101
# 2022-05-17 18:10:03,654 - root - INFO - For store 109update mismatch count5101
# 2022-05-17 18:10:05,147 - root - INFO - Store 122
# 2022-05-17 18:10:05,148 - root - INFO - Total grades calculated398
# 2022-05-17 18:10:05,165 - root - INFO - Grades changed5184
# 2022-05-17 18:10:05,595 - root - INFO - For store 122update mismatch count5184
# 2022-05-17 18:10:06,690 - root - INFO - Store 146
# 2022-05-17 18:10:06,691 - root - INFO - Total grades calculated334
# 2022-05-17 18:10:06,703 - root - INFO - Grades changed4355
# 2022-05-17 18:10:07,057 - root - INFO - For store 146update mismatch count4355
# 2022-05-17 18:10:08,170 - root - INFO - Store 188
# 2022-05-17 18:10:08,170 - root - INFO - Total grades calculated570
# 2022-05-17 18:10:08,185 - root - INFO - Grades changed6541
# 2022-05-17 18:10:08,634 - root - INFO - For store 188update mismatch count6541
# 2022-05-17 18:10:09,996 - root - INFO - Store 190
# 2022-05-17 18:10:09,997 - root - INFO - Total grades calculated285
# 2022-05-17 18:10:10,010 - root - INFO - Grades changed3848
# 2022-05-17 18:10:10,306 - root - INFO - For store 190update mismatch count3848
# 2022-05-17 18:10:11,474 - root - INFO - Store 213
# 2022-05-17 18:10:11,475 - root - INFO - Total grades calculated383
# 2022-05-17 18:10:11,487 - root - INFO - Grades changed5156
# 2022-05-17 18:10:11,841 - root - INFO - For store 213update mismatch count5156
# 2022-05-17 18:10:13,001 - root - INFO - Store 230
# 2022-05-17 18:10:13,002 - root - INFO - Total grades calculated310
# 2022-05-17 18:10:13,017 - root - INFO - Grades changed5036
# 2022-05-17 18:10:13,423 - root - INFO - For store 230update mismatch count5036
# 2022-05-17 18:10:14,561 - root - INFO - Store 233
# 2022-05-17 18:10:14,561 - root - INFO - Total grades calculated257
# 2022-05-17 18:10:14,579 - root - INFO - Grades changed4259
# 2022-05-17 18:10:14,979 - root - INFO - For store 233update mismatch count4259
# 2022-05-17 18:10:16,170 - root - INFO - Store 241
# 2022-05-17 18:10:16,171 - root - INFO - Total grades calculated287
# 2022-05-17 18:10:16,185 - root - INFO - Grades changed3862
# 2022-05-17 18:10:16,714 - root - INFO - For store 241update mismatch count3862
# 2022-05-17 18:10:17,864 - root - INFO - Store 242
# 2022-05-17 18:10:17,865 - root - INFO - Total grades calculated259
# 2022-05-17 18:10:17,880 - root - INFO - Grades changed25245
# 2022-05-17 18:10:18,718 - root - INFO - For store 242update mismatch count25245
# 2022-05-17 18:10:19,984 - root - INFO - Store 258
# 2022-05-17 18:10:19,984 - root - INFO - Total grades calculated257
# 2022-05-17 18:10:19,997 - root - INFO - Grades changed257
# 2022-05-17 18:10:20,215 - root - INFO - For store 258update mismatch count257
# 2022-05-17 18:10:21,264 - root - INFO - Store 251
# 2022-05-17 18:10:21,265 - root - INFO - Total grades calculated169
# 2022-05-17 18:10:21,276 - root - INFO - Grades changed169
# 2022-05-17 18:10:21,564 - root - INFO - For store 251update mismatch count169
# 2022-05-17 18:10:22,638 - root - INFO - Store 244
# 2022-05-17 18:10:22,639 - root - INFO - Total grades calculated251
# 2022-05-17 18:10:22,651 - root - INFO - Grades changed25254
# 2022-05-17 18:10:23,548 - root - INFO - For store 244update mismatch count25254
# 2022-05-17 18:10:24,711 - root - INFO - Store 208
# 2022-05-17 18:10:24,711 - root - INFO - Total grades calculated273
# 2022-05-17 18:10:24,724 - root - INFO - Grades changed4384
# 2022-05-17 18:10:25,314 - root - INFO - For store 208update mismatch count4384
# 2022-05-17 18:10:26,462 - root - INFO - Store 8
# 2022-05-17 18:10:26,463 - root - INFO - Total grades calculated430
# 2022-05-17 18:10:26,474 - root - INFO - Grades changed5107
# 2022-05-17 18:10:26,902 - root - INFO - For store 8update mismatch count5107
# 2022-05-17 18:10:28,022 - root - INFO - Store 19
# 2022-05-17 18:10:28,023 - root - INFO - Total grades calculated437
# 2022-05-17 18:10:28,037 - root - INFO - Grades changed5760
# 2022-05-17 18:10:28,499 - root - INFO - For store 19update mismatch count5760
# 2022-05-17 18:10:29,614 - root - INFO - Store 23
# 2022-05-17 18:10:29,615 - root - INFO - Total grades calculated626
# 2022-05-17 18:10:29,626 - root - INFO - Grades changed5302
# 2022-05-17 18:10:30,386 - root - INFO - For store 23update mismatch count5302
# 2022-05-17 18:10:31,621 - root - INFO - Store 31
# 2022-05-17 18:10:31,621 - root - INFO - Total grades calculated595
# 2022-05-17 18:10:31,637 - root - INFO - Grades changed5344
# 2022-05-17 18:10:32,063 - root - INFO - For store 31update mismatch count5344
# 2022-05-17 18:10:33,466 - root - INFO - Store 79
# 2022-05-17 18:10:33,466 - root - INFO - Total grades calculated329
# 2022-05-17 18:10:33,479 - root - INFO - Grades changed4433
# 2022-05-17 18:10:33,872 - root - INFO - For store 79update mismatch count4433
# 2022-05-17 18:10:35,270 - root - INFO - Store 223
# 2022-05-17 18:10:35,271 - root - INFO - Total grades calculated170
# 2022-05-17 18:10:35,286 - root - INFO - Grades changed4585
# 2022-05-17 18:10:35,658 - root - INFO - For store 223update mismatch count4585
# 2022-05-17 18:10:36,834 - root - INFO - Store 231
# 2022-05-17 18:10:36,835 - root - INFO - Total grades calculated235
# 2022-05-17 18:10:36,848 - root - INFO - Grades changed3206
# 2022-05-17 18:10:37,248 - root - INFO - For store 231update mismatch count3206
# 2022-05-17 18:10:38,658 - root - INFO - Store 240
# 2022-05-17 18:10:38,658 - root - INFO - Total grades calculated294
# 2022-05-17 18:10:38,670 - root - INFO - Grades changed2451
# 2022-05-17 18:10:38,984 - root - INFO - For store 240update mismatch count2451
# 2022-05-17 18:10:40,485 - root - INFO - Store 275
# 2022-05-17 18:10:40,485 - root - INFO - Total grades calculated270
# 2022-05-17 18:10:40,497 - root - INFO - Grades changed270
# 2022-05-17 18:10:41,069 - root - INFO - For store 275update mismatch count270
# 2022-05-17 18:10:42,287 - root - INFO - Store 277
# 2022-05-17 18:10:42,288 - root - INFO - Total grades calculated192
# 2022-05-17 18:10:42,301 - root - INFO - Grades changed192
# 2022-05-17 18:10:42,610 - root - INFO - For store 277update mismatch count192
# 2022-05-17 18:10:43,647 - root - INFO - Store 268
# 2022-05-17 18:10:43,647 - root - INFO - Total grades calculated137
# 2022-05-17 18:10:43,660 - root - INFO - Grades changed137
# 2022-05-17 18:10:43,869 - root - INFO - For store 268update mismatch count137
# 2022-05-17 18:10:44,950 - root - INFO - Store 246
# 2022-05-17 18:10:44,950 - root - INFO - Total grades calculated310
# 2022-05-17 18:10:44,965 - root - INFO - Grades changed25271
# 2022-05-17 18:10:45,800 - root - INFO - For store 246update mismatch count25271
# 2022-05-17 18:10:47,005 - root - INFO - Store 76
# 2022-05-17 18:10:47,006 - root - INFO - Total grades calculated431
# 2022-05-17 18:10:47,019 - root - INFO - Grades changed5568
# 2022-05-17 18:10:47,587 - root - INFO - For store 76update mismatch count5568
# 2022-05-17 18:10:48,719 - root - INFO - Store 96
# 2022-05-17 18:10:48,720 - root - INFO - Total grades calculated513
# 2022-05-17 18:10:48,732 - root - INFO - Grades changed6489
# 2022-05-17 18:10:49,198 - root - INFO - For store 96update mismatch count6489
# 2022-05-17 18:10:50,550 - root - INFO - Store 150
# 2022-05-17 18:10:50,551 - root - INFO - Total grades calculated268
# 2022-05-17 18:10:50,565 - root - INFO - Grades changed3879
# 2022-05-17 18:10:50,885 - root - INFO - For store 150update mismatch count3879
# 2022-05-17 18:10:51,967 - root - INFO - Store 183
# 2022-05-17 18:10:51,967 - root - INFO - Total grades calculated286
# 2022-05-17 18:10:51,979 - root - INFO - Grades changed4488
# 2022-05-17 18:10:52,395 - root - INFO - For store 183update mismatch count4488
# 2022-05-17 18:10:53,555 - root - INFO - Store 222
# 2022-05-17 18:10:53,555 - root - INFO - Total grades calculated435
# 2022-05-17 18:10:53,568 - root - INFO - Grades changed4576
# 2022-05-17 18:10:53,913 - root - INFO - For store 222update mismatch count4576
# 2022-05-17 18:10:55,058 - root - INFO - Store 224
# 2022-05-17 18:10:55,059 - root - INFO - Total grades calculated196
# 2022-05-17 18:10:55,072 - root - INFO - Grades changed4126
# 2022-05-17 18:10:55,508 - root - INFO - For store 224update mismatch count4126
# 2022-05-17 18:10:57,019 - root - INFO - Store 228
# 2022-05-17 18:10:57,019 - root - INFO - Total grades calculated349
# 2022-05-17 18:10:57,033 - root - INFO - Grades changed3927
# 2022-05-17 18:10:57,338 - root - INFO - For store 228update mismatch count3927
# 2022-05-17 18:10:58,989 - root - INFO - Store 245
# 2022-05-17 18:10:58,990 - root - INFO - Total grades calculated224
# 2022-05-17 18:10:59,002 - root - INFO - Grades changed25235
# 2022-05-17 18:10:59,995 - root - INFO - For store 245update mismatch count25235
# 2022-05-17 18:11:01,967 - root - INFO - Store 249
# 2022-05-17 18:11:01,968 - root - INFO - Total grades calculated223
# 2022-05-17 18:11:01,981 - root - INFO - Grades changed25250
# 2022-05-17 18:11:02,963 - root - INFO - For store 249update mismatch count25250
# 2022-05-17 18:11:04,432 - root - INFO - Store 260
# 2022-05-17 18:11:04,432 - root - INFO - Total grades calculated285
# 2022-05-17 18:11:04,444 - root - INFO - Grades changed285
# 2022-05-17 18:11:04,757 - root - INFO - For store 260update mismatch count285
# 2022-05-17 18:11:06,597 - root - INFO - Store 265
# 2022-05-17 18:11:06,597 - root - INFO - Total grades calculated193
# 2022-05-17 18:11:06,609 - root - INFO - Grades changed193
# 2022-05-17 18:11:06,929 - root - INFO - For store 265update mismatch count193
# 2022-05-17 18:11:08,268 - root - INFO - Store 67
# 2022-05-17 18:11:08,268 - root - INFO - Total grades calculated361
# 2022-05-17 18:11:08,280 - root - INFO - Grades changed5881
# 2022-05-17 18:11:08,715 - root - INFO - For store 67update mismatch count5881
# 2022-05-17 18:11:10,039 - root - INFO - Store 262
# 2022-05-17 18:11:10,040 - root - INFO - Total grades calculated143
# 2022-05-17 18:11:10,051 - root - INFO - Grades changed143
# 2022-05-17 18:11:10,332 - root - INFO - For store 262update mismatch count143
# 2022-05-17 18:11:11,521 - root - INFO - Store 266
# 2022-05-17 18:11:11,521 - root - INFO - Total grades calculated160
# 2022-05-17 18:11:11,533 - root - INFO - Grades changed160
# 2022-05-17 18:11:11,782 - root - INFO - For store 266update mismatch count160
# 2022-05-17 18:11:13,311 - root - INFO - Store 82
# 2022-05-17 18:11:13,312 - root - INFO - Total grades calculated361
# 2022-05-17 18:11:13,326 - root - INFO - Grades changed5016
# 2022-05-17 18:11:13,945 - root - INFO - For store 82update mismatch count5016
# 2022-05-17 18:11:15,094 - root - INFO - Store 120
# 2022-05-17 18:11:15,095 - root - INFO - Total grades calculated355
# 2022-05-17 18:11:15,107 - root - INFO - Grades changed5328
# 2022-05-17 18:11:15,551 - root - INFO - For store 120update mismatch count5328
# 2022-05-17 18:11:16,775 - root - INFO - Store 229
# 2022-05-17 18:11:16,775 - root - INFO - Total grades calculated198
# 2022-05-17 18:11:16,787 - root - INFO - Grades changed3269
# 2022-05-17 18:11:17,275 - root - INFO - For store 229update mismatch count3269
# 2022-05-17 18:11:18,951 - root - INFO - Store 226
# 2022-05-17 18:11:18,952 - root - INFO - Total grades calculated333
# 2022-05-17 18:11:18,964 - root - INFO - Grades changed4671
# 2022-05-17 18:11:19,417 - root - INFO - For store 226update mismatch count4671
# 2022-05-17 18:11:20,914 - root - INFO - Store 248
# 2022-05-17 18:11:20,916 - root - INFO - Total grades calculated184
# 2022-05-17 18:11:20,938 - root - INFO - Grades changed25249
# 2022-05-17 18:11:22,760 - root - INFO - For store 248update mismatch count25249
# 2022-05-17 18:11:24,954 - root - INFO - Store 257
# 2022-05-17 18:11:24,954 - root - INFO - Total grades calculated200
# 2022-05-17 18:11:24,967 - root - INFO - Grades changed25235
# 2022-05-17 18:11:26,191 - root - INFO - For store 257update mismatch count25235
# 2022-05-17 18:11:27,797 - root - INFO - Store 235
# 2022-05-17 18:11:27,798 - root - INFO - Total grades calculated326
# 2022-05-17 18:11:27,810 - root - INFO - Grades changed4447
# 2022-05-17 18:11:28,198 - root - INFO - For store 235update mismatch count4447
# 2022-05-17 18:11:29,886 - root - INFO - Store 144
# 2022-05-17 18:11:29,886 - root - INFO - Total grades calculated188
# 2022-05-17 18:11:29,898 - root - INFO - Grades changed3779
# 2022-05-17 18:11:30,504 - root - INFO - For store 144update mismatch count3779
# 2022-05-17 18:11:32,078 - root - INFO - Store 259
# 2022-05-17 18:11:32,078 - root - INFO - Total grades calculated142
# 2022-05-17 18:11:32,090 - root - INFO - Grades changed142
# 2022-05-17 18:11:32,310 - root - INFO - For store 259update mismatch count142
# 2022-05-17 18:11:34,229 - root - INFO - Store 145
# 2022-05-17 18:11:34,229 - root - INFO - Total grades calculated200
# 2022-05-17 18:11:34,242 - root - INFO - Grades changed3857
# 2022-05-17 18:11:34,756 - root - INFO - For store 145update mismatch count3857
# 2022-05-17 18:11:36,587 - root - INFO - Store 263
# 2022-05-17 18:11:36,588 - root - INFO - Total grades calculated325
# 2022-05-17 18:11:36,599 - root - INFO - Grades changed325
# 2022-05-17 18:11:37,415 - root - INFO - For store 263update mismatch count325
# 2022-05-17 18:11:39,162 - root - INFO - Store 267
# 2022-05-17 18:11:39,162 - root - INFO - Total grades calculated217
# 2022-05-17 18:11:39,174 - root - INFO - Grades changed217
# 2022-05-17 18:11:39,354 - root - INFO - For store 267update mismatch count217
# 2022-05-17 18:11:40,669 - root - INFO - Store 271
# 2022-05-17 18:11:40,670 - root - INFO - Total grades calculated117
# 2022-05-17 18:11:40,681 - root - INFO - Grades changed117
# 2022-05-17 18:11:40,887 - root - INFO - For store 271update mismatch count117
# 2022-05-17 18:11:42,808 - root - INFO - Store 186
# 2022-05-17 18:11:42,809 - root - INFO - Total grades calculated225
# 2022-05-17 18:11:42,821 - root - INFO - Grades changed4183
# 2022-05-17 18:11:43,225 - root - INFO - For store 186update mismatch count4183
# 2022-05-17 18:11:46,451 - root - INFO - Store 273
# 2022-05-17 18:11:46,452 - root - INFO - Total grades calculated191
# 2022-05-17 18:11:46,463 - root - INFO - Grades changed191
# 2022-05-17 18:11:46,875 - root - INFO - For store 273update mismatch count191
# 2022-05-17 18:11:49,703 - root - INFO - Store 272
# 2022-05-17 18:11:49,704 - root - INFO - Total grades calculated118
# 2022-05-17 18:11:49,715 - root - INFO - Grades changed118
# 2022-05-17 18:11:50,032 - root - INFO - For store 272update mismatch count118
# 2022-05-17 18:11:52,072 - root - INFO - Store 274
# 2022-05-17 18:11:52,072 - root - INFO - Total grades calculated143
# 2022-05-17 18:11:52,083 - root - INFO - Grades changed143
# 2022-05-17 18:11:52,313 - root - INFO - For store 274update mismatch count143
# 2022-05-17 18:11:54,370 - root - INFO - Store 217
# 2022-05-17 18:11:54,371 - root - INFO - Total grades calculated265
# 2022-05-17 18:11:54,383 - root - INFO - Grades changed3829
# 2022-05-17 18:11:54,958 - root - INFO - For store 217update mismatch count3829
# 2022-05-17 18:11:57,069 - root - INFO - Store 198
# 2022-05-17 18:11:57,070 - root - INFO - Total grades calculated411
# 2022-05-17 18:11:57,082 - root - INFO - Grades changed4627
# 2022-05-17 18:11:57,882 - root - INFO - For store 198update mismatch count4627
# 2022-05-17 18:11:59,408 - root - INFO - Store 250
# 2022-05-17 18:11:59,408 - root - INFO - Total grades calculated112
# 2022-05-17 18:11:59,421 - root - INFO - Grades changed25235
# 2022-05-17 18:12:00,496 - root - INFO - For store 250update mismatch count25235
# 's3://aws-glue-temporary-921939243643-ap-south-1/drug_grades/              id  store_id  drug_id drug_grade drug_grade_updated\n0      256738211       285   488932         A2                NaN\n1      256833408       285   489554          C                NaN\n2      256925659       285   490362         A2                NaN\n3      264257195       285    22047         A2                NaN\n4      264257248       285    27237         A2                NaN\n...          ...       ...      ...        ...                ...\n25230  256752150       250   489028          C                NaN\n25231  256799186       250   489337          C                NaN\n25232  256800590       250   489346          C                NaN\n25233  269826391       250   491870          C                NaN\n25234  269178792       250   491603         A2                NaN\n\n[835012 rows x 5 columns].csv'

# %%
rs_db.close_connection()

rs_db_write.close_connection()
# Out:
# Redshift DB connection closed successfully.
# Redshift DB connection closed successfully.
